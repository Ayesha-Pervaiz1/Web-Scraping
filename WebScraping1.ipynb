# %%
print("helo")
# Out:
# helo

# %%
#Code for scraping all women rings
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)
    # Find all hyperlinks in the page
    links = soup.find_all('a')
    print("\nAll Hyperlinks:")
    for link in links:
        href = link.get('href')
        print(href)
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# All Hyperlinks:
# https://emori.in
# https://emori.in/
# https://emori.in/shop/
# https://emori.in/product-category/ring/
# https://emori.in/product-category/ring/
# https://emori.in/product-category/ring/
# https://emori.in/product-category/ring/engagement-rings/
# https://emori.in/product-category/ring/solitaire-rings/
# https://emori.in/product-category/ring/daily-wear-rings/
# https://emori.in/product-category/ring/promise-rings/
# https://emori.in/product-category/ring/gemstone-rings/
# https://emori.in/product-category/ring/bands/
# https://emori.in/product-category/mens-rings/
# https://emori.in/product-category/ring/couple-rings/
# https://emori.in/product-category/earring/
# https://emori.in/product-category/earring/womens-earring/
# https://emori.in/product-category/earring/womens-earring/
# https://emori.in/product-category/earring/solitaire-studs/
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)

    # Find the main container holding the products
    main_container = soup.find(class_="content-cat.row")
    if main_container:
        print("\nMain Container found!")

        # Find all individual product containers within the main container
        # product_containers = main_container.find_all('div', class_="woocommerce-notices-wrapper")   #page > div.content-cat.row > div.site-content.shop-content-area.col-lg-10.col-12.col-md-9.description-area-after.content-with-products.wd-builder-off > div.woocommerce-notices-wrapper
        # print(f"Found {len(product_containers)} products:\n")

        # for product in product_containers:
        #     # Extract product title
        #     product_title = product.find('h2', class_="woocommerce-loop-product__title")
        #     product_title = product_title.text if product_title else "No title"
            
        #     # Extract product price
        #     product_price = product.find('span', class_="woocommerce-Price-amount")
        #     product_price = product_price.text if product_price else "No price"
            
        #     # Extract product link
        #     product_link = product.find('a', href=True)
        #     product_link = product_link['href'] if product_link else "No link"
            
        #     print(f"Title: {product_title}")
        #     print(f"Price: {product_price}")
        #     print(f"Link: {product_link}\n")
    else:
        print("Main container not found.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
# Main container not found.

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)

    # Print the entire HTML to debug structure
    # print(soup.prettify())  # Uncomment to view full HTML structure

    # Find the main container holding the products
    main_container = soup.find('div', class_="site-content shop-content-area col-lg-10 col-12 col-md-9 description-area-after content-with-products wd-builder-off")
    if main_container:
        print("\nMain Container found!")

        # Find all individual product containers within the main container
        product_containers = main_container.find_all('div', class_="product-wrapper")
        print(f"Found {len(product_containers)} products:\n")

        for product in product_containers:
            # Extract product title
            product_title = product.find('h2', class_="woocommerce-loop-product__title")
            product_title = product_title.text if product_title else "No title"
            
            # Extract product price
            product_price = product.find('span', class_="woocommerce-Price-amount")
            product_price = product_price.text if product_price else "No price"
            
            # Extract product link
            product_link = product.find('a', href=True)
            product_link = product_link['href'] if product_link else "No link"
            
            print(f"Title: {product_title}")
            print(f"Price: {product_price}")
            print(f"Link: {product_link}\n")
    else:
        print("Main container not found. The class name might be incorrect or content is dynamically rendered.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 products:
#
# Title: No title
# Price: ₹28,390
# Link: https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/
#
# Title: No title
# Price: ₹42,112
# Link: https://emori.in/product/princess-cut-splendor-ring-in-14kt-gold-or-18kt-gold/
#
# Title: No title
# Price: ₹11,260
# Link: https://emori.in/product/shimmery-classic-diamond-band-in-14kt-gold-or-18kt-gold/
#
# Title: No title
# Price: ₹48,556
# Link: https://emori.in/product/ashez-diamond-ring/
#
# Title: No title
# Price: ₹46,621
# Link: https://emori.in/product/regal-splendor-diamond-ring-in-14kt-gold-or-18kt-gold/
#
# Title: No title
# Price: ₹47,813
# Link: https://emori.in/product/pear-and-emerald-diamond-band/
#
# Title: No title
# Price: ₹30,061
# Link: https://emori.in/product/classic-ira-solitaire-ring/
#
# Title: No title
# Price: ₹85,424
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)

    # Print the entire HTML to debug structure
    # print(soup.prettify())  # Uncomment to view full HTML structure

    # Find the main container holding the products
    main_container = soup.find('div', class_="site-content shop-content-area col-lg-10 col-12 col-md-9 description-area-after content-with-products wd-builder-off")
    if main_container:
        print("\nMain Container found!")

        # Find all individual product containers within the main container
        product_containers = main_container.find_all('div', class_="wd-products-element")
        print(f"Found {len(product_containers)} products:\n")

        for product in product_containers:
            # Extract product title
            product_title = product.find('h2', class_="woocommerce-loop-product__title")
            product_title = product_title.text if product_title else "No title"
            
            # Extract product price
            product_price = product.find('span', class_="woocommerce-Price-amount")
            product_price = product_price.text if product_price else "No price"
            
            # Extract product link
            product_link = product.find('a', href=True)
            product_link = product_link['href'] if product_link else "No link"
            
            print(f"Title: {product_title}")
            print(f"Price: {product_price}")
            print(f"Link: {product_link}\n")
    else:
        print("Main container not found. The class name might be incorrect or content is dynamically rendered.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 1 products:
#
# Title: No title
# Price: ₹28,390
# Link: https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)

    # Find the main container with class 'wd-products-element'
    main_container = soup.find('div', class_="wd-products-element")
    if main_container:
        print("\nMain Container found!")

        # Find all child elements within the container
        product_elements = main_container.find_all('div', class_="product")
        print(f"Found {len(product_elements)} product elements.\n")

        # Loop through each product element
        for product in product_elements:
            # Extract the 'data-loop' attribute
            data_loop = product.get('data-loop', 'No data-loop')

            # Extract the 'data-id' attribute
            data_id = product.get('data-id', 'No data-id')

            # Print the attributes
            print(f"Data Loop: {data_loop}, Data ID: {data_id}")

            # Extract additional product details, like title or price
            product_title = product.find('h2', class_="woocommerce-loop-product__title")
            product_title = product_title.text.strip() if product_title else "No title"
            
            product_price = product.find('span', class_="woocommerce-Price-amount")
            product_price = product_price.text.strip() if product_price else "No price"

            print(f"Title: {product_title}")
            print(f"Price: {product_price}\n")
    else:
        print("Main container 'wd-products-element' not found.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 product elements.
#
# Data Loop: 1, Data ID: 3278
# Title: No title
# Price: ₹28,390
#
# Data Loop: 2, Data ID: 7249
# Title: No title
# Price: ₹42,112
#
# Data Loop: 3, Data ID: 7254
# Title: No title
# Price: ₹11,260
#
# Data Loop: 4, Data ID: 12303
# Title: No title
# Price: ₹48,556
#
# Data Loop: 5, Data ID: 6427
# Title: No title
# Price: ₹46,621
#
# Data Loop: 6, Data ID: 10607
# Title: No title
# Price: ₹47,813
#
# Data Loop: 7, Data ID: 17750
# Title: No title
# Price: ₹30,061
#
# Data Loop: 8, Data ID: 17752
# Title: No title
# Price: ₹85,424
#
# Data Loop: 9, Data ID: 21380
# Title: No title
# Price: ₹43,709
#
# Data Loop: 10, Data ID: 3270
# Title: No title
# Price: ₹29,824
#
# Data Loop: 11, Data ID: 3276
# Title: No title
# Price: ₹26,839
#
# Data Loop: 12, Data ID: 6432
# Title: No title
# Price: ₹55,755
#
# Data Loop: 13, Data ID: 3274
# Title: No title
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)

    # Find the main container with class 'wd-products-element'
    main_container = soup.find('div', class_="wd-products-element")
    if main_container:
        print("\nMain Container found!")

        # Find all product elements
        product_elements = main_container.find_all('div', class_="product")
        print(f"Found {len(product_elements)} product elements.\n")

        for product in product_elements:
            # Debug: Print full product HTML
            print("\nProduct HTML:\n", product.prettify())

            # Extract attributes
            data_loop = product.get('data-loop', 'No data-loop')
            data_id = product.get('data-id', 'No data-id')

            # Extract product title
            product_title = product.find('h2', class_="woocommerce-loop-product__title")
            product_title = product_title.text.strip() if product_title else "No title"
            
            # Extract product price
            product_price = product.find('span', class_="woocommerce-Price-amount")
            product_price = product_price.text.strip() if product_price else "No price"

            print(f"Data Loop: {data_loop}, Data ID: {data_id}")
            print(f"Title: {product_title}")
            print(f"Price: {product_price}\n")
    else:
        print("Main container 'wd-products-element' not found.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 product elements.
#
#
# Product HTML:
#  <div class="wd-product wd-with-labels wd-hover-icons wd-col product-grid-item product type-product post-3278 status-publish instock product_cat-anniversary-rings product_cat-diwali-special-rings product_cat-engagement-rings product_cat-gifts-for-wife product_cat-halo-rings product_cat-ring product_cat-rings-for-wife product_cat-statement-wear product_cat-the-party-edit product_tag-sale-product has-post-thumbnail sale featured shipping-taxable purchasable product-type-variable has-default-attributes" data-id="3278" data-loop="1">
#  <div class="product-wrapper">
#   <div class="product-element-top wd-quick-shop">
#    <a class="product-image-link" href="https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/">
#     <div class="product-labels labels-rectangular">
#      <span class="onsale product-label">
#       -4%
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)

    # Find the main container with class 'wd-products-element'
    main_container = soup.find('div', class_="wd-products-element")
    if main_container:
        print("\nMain Container found!")

        # Find all product elements
        product_elements = main_container.find_all('div', class_="product")
        print(f"Found {len(product_elements)} product elements.\n")

        for product in product_elements:
            # Extract attributes
            data_loop = product.get('data-loop', 'No data-loop')
            data_id = product.get('data-id', 'No data-id')

            # Extract product title from the anchor tag
            title_tag = product.find('a', class_="product-image-link")
            product_title = title_tag['href'].split('/')[-2].replace('-', ' ') if title_tag else "No title"
            
            # Extract product price
            product_price = product.find('span', class_="woocommerce-Price-amount")
            product_price = product_price.text.strip() if product_price else "No price"
            
            # Extract product link
            product_link = title_tag['href'] if title_tag else "No link"
            
            # Extract product image URL
            product_image = product.find('img', class_="attachment-woocommerce_thumbnail")
            product_image_url = product_image['src'] if product_image else "No image"

            print(f"Data Loop: {data_loop}, Data ID: {data_id}")
            print(f"Title: {product_title}")
            print(f"Price: {product_price}")
            print(f"Link: {product_link}")
            print(f"Image URL: {product_image_url}\n")
    else:
        print("Main container 'wd-products-element' not found.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 product elements.
#
# Data Loop: 1, Data ID: 3278
# Title: queen solitaire diamond ring in 14kt gold or 18kt gold
# Price: ₹28,390
# Link: https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/07/R7253-300x300.jpg
#
# Data Loop: 2, Data ID: 7249
# Title: princess cut splendor ring in 14kt gold or 18kt gold
# Price: ₹42,112
# Link: https://emori.in/product/princess-cut-splendor-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/10/R1098-1-300x300.webp
#
# Data Loop: 3, Data ID: 7254
# Title: shimmery classic diamond band in 14kt gold or 18kt gold
# Price: ₹11,260
# Link: https://emori.in/product/shimmery-classic-diamond-band-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/10/R1103-1-300x300.webp
#
# Data Loop: 4, Data ID: 12303
# ...

# %%
#Convert in csv file 
import requests
from bs4 import BeautifulSoup
import csv

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Open a CSV file to write the data
with open('product_details.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Title", "Price", "Link", "Image URL"])  # Write headers

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract the title of the page
        page_title = soup.title.string
        print("Page Title:", page_title)

        # Find the main container with class 'wd-products-element'
        main_container = soup.find('div', class_="wd-products-element")
        if main_container:
            print("\nMain Container found!")

            # Find all product elements
            product_elements = main_container.find_all('div', class_="product")
            print(f"Found {len(product_elements)} product elements.\n")

            for product in product_elements:
                # Extract attributes
                # data_loop = product.get('data-loop', 'No data-loop')
                # data_id = product.get('data-id', 'No data-id')

                # Extract product title from the anchor tag
                title_tag = product.find('a', class_="product-image-link")
                product_title = title_tag['href'].split('/')[-2].replace('-', ' ') if title_tag else "No title"
                
                # Extract product price
                product_price = product.find('span', class_="woocommerce-Price-amount")
                product_price = product_price.text.strip() if product_price else "No price"
                
                # Extract product link
                product_link = title_tag['href'] if title_tag else "No link"
                
                # Extract product image URL
                product_image = product.find('img', class_="attachment-woocommerce_thumbnail")
                product_image_url = product_image['src'] if product_image else "No image"

                # Print the extracted data (optional)
                # print(f"Data Loop: {data_loop}, Data ID: {data_id}")
                print(f"Title: {product_title}")
                print(f"Price: {product_price}")
                print(f"Link: {product_link}")
                print(f"Image URL: {product_image_url}\n")

                # Write the data to CSV
                writer.writerow([product_title, product_price, product_link, product_image_url])

        else:
            print("Main container 'wd-products-element' not found.")
    else:
        print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 product elements.
#
# Title: queen solitaire diamond ring in 14kt gold or 18kt gold
# Price: ₹28,390
# Link: https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/07/R7253-300x300.jpg
#
# Title: princess cut splendor ring in 14kt gold or 18kt gold
# Price: ₹42,112
# Link: https://emori.in/product/princess-cut-splendor-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/10/R1098-1-300x300.webp
#
# Title: shimmery classic diamond band in 14kt gold or 18kt gold
# Price: ₹11,260
# Link: https://emori.in/product/shimmery-classic-diamond-band-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/10/R1103-1-300x300.webp
#
# Title: ashez diamond ring
# Price: ₹48,556
# Link: https://emori.in/product/ashez-diamond-ring/
# ...

# %%
#Extract data according to the jewelry System ,extrat all images (products) and all all metadata of respective images  
import requests
from bs4 import BeautifulSoup
import csv

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Open a CSV file to write the data
with open('product_details.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Title", "Price", "Link", "Image URL", "Image Alt", "Image Srcset"])  # Write headers

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract the title of the page
        page_title = soup.title.string
        print("Page Title:", page_title)

        # Find the main container with class 'wd-products-element'
        main_container = soup.find('div', class_="wd-products-element")
        if main_container:
            print("\nMain Container found!")

            # Find all product elements
            product_elements = main_container.find_all('div', class_="product")
            print(f"Found {len(product_elements)} product elements.\n")

            for product in product_elements:

                # Extract product title from the anchor tag
                title_tag = product.find('a', class_="product-image-link")
                product_title = title_tag['href'].split('/')[-2].replace('-', ' ') if title_tag else "No title"
                
                # Extract product price
                product_price = product.find('span', class_="woocommerce-Price-amount")
                product_price = product_price.text.strip() if product_price else "No price"
                
                # Extract product link
                product_link = title_tag['href'] if title_tag else "No link"
                
                # Extract product image URL
                product_image = product.find('img', class_="attachment-woocommerce_thumbnail")
                product_image_url = product_image['src'] if product_image else "No image URL"
                
                # Extract image alt text (optional)
                product_image_alt = product_image['alt'] if product_image else "No alt text"
                
                # Extract image srcset (optional, for multiple image sizes)
                product_image_srcset = product_image['srcset'] if product_image else "No srcset"

                # Print the extracted data (optional)
                print(f"Title: {product_title}")
                print(f"Price: {product_price}")
                print(f"Link: {product_link}")
                print(f"Image URL: {product_image_url}")
                print(f"Image Alt: {product_image_alt}")
                print(f"Image Srcset: {product_image_srcset}\n")

                # Write the data to CSV
                writer.writerow([product_title, product_price, product_link, product_image_url, product_image_alt, product_image_srcset])

        else:
            print("Main container 'wd-products-element' not found.")
    else:
        print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 product elements.
#
# Title: queen solitaire diamond ring in 14kt gold or 18kt gold
# Price: ₹28,390
# Link: https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/07/R7253-300x300.jpg
# Image Alt: Queen Solitaire Diamond Ring Front view
# Image Srcset: https://emori.in/wp-content/uploads/2023/07/R7253-300x300.jpg 300w, https://emori.in/wp-content/uploads/2023/07/R7253-1024x1024.jpg 1024w, https://emori.in/wp-content/uploads/2023/07/R7253-150x150.jpg 150w, https://emori.in/wp-content/uploads/2023/07/R7253-768x768.jpg 768w, https://emori.in/wp-content/uploads/2023/07/R7253-1536x1536.jpg 1536w, https://emori.in/wp-content/uploads/2023/07/R7253-600x600.jpg 600w, https://emori.in/wp-content/uploads/2023/07/R7253.jpg 2000w
#
# Title: princess cut splendor ring in 14kt gold or 18kt gold
# Price: ₹42,112
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)
    
    # Find the main container holding the products
    main_container = soup.find('div', class_="site-content shop-content-area col-lg-10 col-12 col-md-9 description-area-after content-with-products wd-builder-off")
    if main_container:
        print("\nMain Container found!")

        # Find all individual product containers within the main container
        product_containers = main_container.find_all('div', class_="wd-product")
        print(f"Found {len(product_containers)} products.\n")

        # Open CSV file to write the results
        with open("products.csv", "w", newline='', encoding='utf-8') as csvfile:
            fieldnames = ['Title', 'Price', 'Link', 'Image URL', 'Description']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            # Write header to the CSV file
            writer.writeheader()

            # Loop through each product and extract the necessary details
            for product in product_containers:
                # Extract product title (link)
                title_tag = product.find('a', class_="product-image-link")
                product_title = title_tag['href'].split('/')[-2].replace('-', ' ') if title_tag else "No title"
                
                # Extract product price
                price_tag = product.find('span', class_="woocommerce-Price-amount")
                product_price = price_tag.text if price_tag else "No price"
                
                # Extract product link
                product_link = title_tag['href'] if title_tag else "No link"
                
                # Extract product image URL
                image_tag = product.find('img')
                product_image_url = image_tag['src'] if image_tag else "No image URL"

                # Visit the product page to scrape description
                product_page = requests.get(product_link)
                if product_page.status_code == 200:
                    product_page_soup = BeautifulSoup(product_page.content, 'html.parser')
                    # Extract product description from the product page
                    description_tag = product_page_soup.find('div', class_="woocommerce-product-details__short-description")
                    product_description = description_tag.get_text(strip=True) if description_tag else "No description"
                else:
                    product_description = "Failed to retrieve description"

                # Print the product information
                print(f"Data Loop: {product_containers.index(product) + 1}")
                print(f"Title: {product_title}")
                print(f"Price: {product_price}")
                print(f"Link: {product_link}")
                print(f"Image URL: {product_image_url}")
                print(f"Description: {product_description}\n")
                
                # Write product information to the CSV file
                writer.writerow({
                    'Title': product_title,
                    'Price': product_price,
                    'Link': product_link,
                    'Image URL': product_image_url,
                    'Description': product_description
                })

    else:
        print("Main container not found. The class name might be incorrect or content is dynamically rendered.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 products.
#
# Data Loop: 1
# Title: queen solitaire diamond ring in 14kt gold or 18kt gold
# Price: ₹28,390
# Link: https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/07/R7253-300x300.jpg
# Description: Diamond: Lab Grown DiamondShape: RoundColour: E-FClarity: VSCut: ExcellentDiamond Total Weight: 0.48 CaratsCenter Diamond Weight: 0.26 CaratsMetal: BIS Hallmarked Gold
#
# Data Loop: 2
# Title: princess cut splendor ring in 14kt gold or 18kt gold
# Price: ₹42,112
# Link: https://emori.in/product/princess-cut-splendor-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/10/R1098-1-300x300.webp
# ...

# %%
#Description Extraction 
import requests
from bs4 import BeautifulSoup
import csv

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)
    
    # Find the main container holding the products
    main_container = soup.find('div', class_="site-content shop-content-area col-lg-10 col-12 col-md-9 description-area-after content-with-products wd-builder-off")
    if main_container:
        print("\nMain Container found!")

        # Find all individual product containers within the main container
        product_containers = main_container.find_all('div', class_="wd-product")
        print(f"Found {len(product_containers)} products.\n")

        # Open CSV file to write the results
        with open("products.csv", "w", newline='', encoding='utf-8') as csvfile:
            fieldnames = ['Title', 'Price', 'Link', 'Image URL', 'Description']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            # Write header to the CSV file
            writer.writeheader()

            # Loop through each product and extract the necessary details
            for product in product_containers:
                # Extract product title (link)
                title_tag = product.find('a', class_="product-image-link")
                product_title = title_tag['href'].split('/')[-2].replace('-', ' ') if title_tag else "No title"
                
                # Extract product price
                price_tag = product.find('span', class_="woocommerce-Price-amount")
                product_price = price_tag.text if price_tag else "No price"
                
                # Extract product link
                product_link = title_tag['href'] if title_tag else "No link"
                
                # Extract product image URL
                image_tag = product.find('img')
                product_image_url = image_tag['src'] if image_tag else "No image URL"

                # Visit the product page to scrape description
                product_page = requests.get(product_link)
                if product_page.status_code == 200:
                    product_page_soup = BeautifulSoup(product_page.content, 'html.parser')
                    # Extract product description from the product page
                    description_tag = product_page_soup.find('div', class_="woocommerce-product-details__short-description")
                    if description_tag:
                        # Extract only the <p> tag content (diamond details)
                        description_p_tag = description_tag.find('p')
                        product_description = description_p_tag.get_text(strip=True) if description_p_tag else "No description"
                    else:
                        product_description = "No description"
                else:
                    product_description = "Failed to retrieve description"

                # Print the product information
                print(f"Data Loop: {product_containers.index(product) + 1}")
                print(f"Title: {product_title}")
                print(f"Price: {product_price}")
                print(f"Link: {product_link}")
                print(f"Image URL: {product_image_url}")
                print(f"Description: {product_description}\n")
                
                # Write product information to the CSV file
                writer.writerow({
                    'Title': product_title,
                    'Price': product_price,
                    'Link': product_link,
                    'Image URL': product_image_url,
                    'Description': product_description
                })

    else:
        print("Main container not found. The class name might be incorrect or content is dynamically rendered.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 products.
#
# Data Loop: 1
# Title: queen solitaire diamond ring in 14kt gold or 18kt gold
# Price: ₹28,390
# Link: https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/07/R7253-300x300.jpg
# Description: Diamond: Lab Grown DiamondShape: RoundColour: E-FClarity: VSCut: ExcellentDiamond Total Weight: 0.48 CaratsCenter Diamond Weight: 0.26 CaratsMetal: BIS Hallmarked Gold
#
# Data Loop: 2
# Title: princess cut splendor ring in 14kt gold or 18kt gold
# Price: ₹42,112
# Link: https://emori.in/product/princess-cut-splendor-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/10/R1098-1-300x300.webp
# ...

# %%
# This storing all description in description heading ---pandas can be used to extract required results
import requests
from bs4 import BeautifulSoup
import csv

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)
    
    # Find the main container holding the products
    main_container = soup.find('div', class_="site-content shop-content-area col-lg-10 col-12 col-md-9 description-area-after content-with-products wd-builder-off")
    if main_container:
        print("\nMain Container found!")

        # Find all individual product containers within the main container
        product_containers = main_container.find_all('div', class_="wd-product")
        print(f"Found {len(product_containers)} products.\n")

        # Open CSV file to write the results
        with open("products.csv", "w", newline='', encoding='utf-8') as csvfile:
            fieldnames = ['Title', 'Price', 'Link', 'Image URL', 'Description']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            # Write header to the CSV file
            writer.writeheader()

            # Loop through each product and extract the necessary details
            for product in product_containers:
                # Extract product title (link)
                title_tag = product.find('a', class_="product-image-link")
                product_title = title_tag['href'].split('/')[-2].replace('-', ' ') if title_tag else "No title"
                
                # Extract product price
                price_tag = product.find('span', class_="woocommerce-Price-amount")
                product_price = price_tag.text if price_tag else "No price"
                
                # Extract product link
                product_link = title_tag['href'] if title_tag else "No link"
                
                # Extract product image URL
                image_tag = product.find('img')
                product_image_url = image_tag['src'] if image_tag else "No image URL"

                # Visit the product page to scrape description
                product_page = requests.get(product_link)
                if product_page.status_code == 200:
                    product_page_soup = BeautifulSoup(product_page.content, 'html.parser')
                    # Extract product description from the product page
                    description_tag = product_page_soup.find('div', class_="woocommerce-product-details__short-description")
                    if description_tag:
                        # Extract only the <p> tag content (diamond details)
                        description_p_tag = description_tag.find('p')
                        product_description = description_p_tag.get_text(strip=True) if description_p_tag else "No description"
                    else:
                        product_description = "No description"
                else:
                    product_description = "Failed to retrieve description"

                # Print the product information
                print(f"Data Loop: {product_containers.index(product) + 1}")
                print(f"Title: {product_title}")
                print(f"Price: {product_price}")
                print(f"Link: {product_link}")
                print(f"Image URL: {product_image_url}")
                print(f"Description: {product_description}\n")
                
                # Write product information to the CSV file
                writer.writerow({
                    'Title': product_title,
                    'Price': product_price,
                    'Link': product_link,
                    'Image URL': product_image_url,
                    'Description': product_description
                })

    else:
        print("Main container not found. The class name might be incorrect or content is dynamically rendered.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 products.
#
# Data Loop: 1
# Title: queen solitaire diamond ring in 14kt gold or 18kt gold
# Price: ₹28,390
# Link: https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/07/R7253-300x300.jpg
# Description: Diamond: Lab Grown DiamondShape: RoundColour: E-FClarity: VSCut: ExcellentDiamond Total Weight: 0.48 CaratsCenter Diamond Weight: 0.26 CaratsMetal: BIS Hallmarked Gold
#
# Data Loop: 2
# Title: princess cut splendor ring in 14kt gold or 18kt gold
# Price: ₹42,112
# Link: https://emori.in/product/princess-cut-splendor-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/10/R1098-1-300x300.webp
# ...

# %%
#Extract description accordin to project requirement     ---This is not working like it should do   --- It is required to make respective heading in csv and fill respective data like -> Diamond: Lab Grown DiamondShape: Round, PrincessColour: E-FClarity: VSCut: BrilliantDiamond Total Weight: 1.19 CaratsCenter Diamond Weight: 0.88 CaratsMetal: BIS Hallmarked Gold
import requests
from bs4 import BeautifulSoup
import csv

# URL of the webpage to scrape
url = "https://emori.in/product-category/ring/"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the title of the page
    page_title = soup.title.string
    print("Page Title:", page_title)
    
    # Find the main container holding the products
    main_container = soup.find('div', class_="site-content shop-content-area col-lg-10 col-12 col-md-9 description-area-after content-with-products wd-builder-off")
    if main_container:
        print("\nMain Container found!")

        # Find all individual product containers within the main container
        product_containers = main_container.find_all('div', class_="wd-product")
        print(f"Found {len(product_containers)} products.\n")

        # Open CSV file to write the results
        with open("products_metadata.csv", "w", newline='', encoding='utf-8') as csvfile:
            fieldnames = ['Title', 'Price', 'Link', 'Image URL', 'Diamond', 'Shape', 'Colour', 'Clarity', 'Cut', 'Diamond Total Weight', 'Metal']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            # Write header to the CSV file
            writer.writeheader()

            # Loop through each product and extract the necessary details
            for product in product_containers:
                # Extract product title (link)
                title_tag = product.find('a', class_="product-image-link")
                product_title = title_tag['href'].split('/')[-2].replace('-', ' ') if title_tag else "No title"
                
                # Extract product price
                price_tag = product.find('span', class_="woocommerce-Price-amount")
                product_price = price_tag.text if price_tag else "No price"
                
                # Extract product link
                product_link = title_tag['href'] if title_tag else "No link"
                
                # Extract product image URL
                image_tag = product.find('img')
                product_image_url = image_tag['src'] if image_tag else "No image URL"

                # Visit the product page to scrape description
                product_page = requests.get(product_link)
                if product_page.status_code == 200:
                    product_page_soup = BeautifulSoup(product_page.content, 'html.parser')
                    # Extract product description from the product page
                    description_tag = product_page_soup.find('div', class_="woocommerce-product-details__short-description")
                    if description_tag:
                        # Extract the content of the <p> tag inside the description
                        description_p_tag = description_tag.find('p')
                        description_text = description_p_tag.get_text(strip=True) if description_p_tag else "No description"
                        
                        # Split description into key-value pairs (assuming <br> tags separate them)
                        description_lines = description_text.split("\n")
                        description_dict = {}
                        
                        # Map each line of the description to the corresponding key
                        for line in description_lines:
                            if ':' in line:
                                key, value = line.split(":", 1)
                                description_dict[key.strip()] = value.strip()

                        # Extract each description detail for CSV
                        diamond = description_dict.get('Diamond', 'No Diamond')
                        shape = description_dict.get('Shape', 'No Shape')
                        colour = description_dict.get('Colour', 'No Colour')
                        clarity = description_dict.get('Clarity', 'No Clarity')
                        cut = description_dict.get('Cut', 'No Cut')
                        diamond_total_weight = description_dict.get('Diamond Total Weight', 'No Diamond Weight')
                        metal = description_dict.get('Metal', 'No Metal')
                    else:
                        diamond, shape, colour, clarity, cut, diamond_total_weight, metal = ["No description"] * 7
                else:
                    diamond, shape, colour, clarity, cut, diamond_total_weight, metal = ["Failed to retrieve"] * 7

                # Print the product information
                print(f"Data Loop: {product_containers.index(product) + 1}")
                print(f"Title: {product_title}")
                print(f"Price: {product_price}")
                print(f"Link: {product_link}")
                print(f"Image URL: {product_image_url}")
                print(f"Description: {diamond}, {shape}, {colour}, {clarity}, {cut}, {diamond_total_weight}, {metal}\n")
                
                # Write product information to the CSV file
                writer.writerow({
                    'Title': product_title,
                    'Price': product_price,
                    'Link': product_link,
                    'Image URL': product_image_url,
                    'Diamond': diamond,
                    'Shape': shape,
                    'Colour': colour,
                    'Clarity': clarity,
                    'Cut': cut,
                    'Diamond Total Weight': diamond_total_weight,
                    'Metal': metal
                })

    else:
        print("Main container not found. The class name might be incorrect or content is dynamically rendered.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Page Title: Lab Grown Diamond Rings | 30 days Free Return - Emori
#
# Main Container found!
# Found 24 products.
#
# Data Loop: 1
# Title: queen solitaire diamond ring in 14kt gold or 18kt gold
# Price: ₹28,390
# Link: https://emori.in/product/queen-solitaire-diamond-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/07/R7253-300x300.jpg
# Description: Lab Grown DiamondShape: RoundColour: E-FClarity: VSCut: ExcellentDiamond Total Weight: 0.48 CaratsCenter Diamond Weight: 0.26 CaratsMetal: BIS Hallmarked Gold, No Shape, No Colour, No Clarity, No Cut, No Diamond Weight, No Metal
#
# Data Loop: 2
# Title: princess cut splendor ring in 14kt gold or 18kt gold
# Price: ₹42,112
# Link: https://emori.in/product/princess-cut-splendor-ring-in-14kt-gold-or-18kt-gold/
# Image URL: https://emori.in/wp-content/uploads/2023/10/R1098-1-300x300.webp
# ...
